# %%
#  _____ __  __ _   _           _   _ _   _
# |  ___|  \/  | | | |         | \ | | \ | |
# | |_  | |\/| | | | |  _____  |  \| |  \| |
# |  _| | |  | | |_| | |_____| | |\  | |\  |
# |_|   |_|  |_|\___/          |_| \_|_| \_|
#
"""
 @authors: Matteo Larcher
"""


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# import libraries
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

import numpy as np
import tensorflow as tf
from plotly import graph_objects as go
from plotly.subplots import make_subplots
import os

# custom libraries
from FMU_layer import *

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# 2024-10-30 11:49:08.250731: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configs

# set keras float precision
tf.keras.backend.set_floatx('float32')

# set eager execution
tf.config.run_functions_eagerly(False)

# set random seeds
tf.keras.utils.set_random_seed(123)

# %%
start_time = 0.0
stop_time = 20.0
step_size = 0.1

# %%
dirname = os.getcwd()
fmu_path = os.path.join(dirname, "fmu_model", "xy_model_om_dd.fmu")

# %%
# result vector
res = []
# time vector
t_vect = np.arange(start_time, stop_time, step_size)

# %%
# Test the FMU layer
start_values = [0.0, 0.0]
parameters = [1.0]
input_x = np.cos(t_vect).astype(tf.keras.backend.floatx()).reshape(1, -1)
input_y = np.sin(t_vect).astype(tf.keras.backend.floatx()).reshape(1, -1)
input_data = tf.Variable(tf.stack([input_x, input_y], axis=2), dtype=tf.keras.backend.floatx(), trainable=True)

fmu_layer = FMULayer(
    fmu_path,
    start_time,
    start_values,
    parameters,
    step_size,
    return_sequences=True,
    return_state=False,
    stateful=True,
    name="test_fmu_layer",
)

output = fmu_layer(input_data)

# Plot the results
fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=t_vect, y=input_x[0], name="Input x", mode="lines"), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=input_y[0], name="Input y", mode="lines"), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=output[0][:,0], name="z", mode="lines"), row=2, col=1)
fig.update_layout(title="FMU Layer Test", xaxis_title="Time [s]", yaxis_title="Value")
fig.show()
# Out:
# Queue length:  0

# %%
# Test the layer gradient

with tf.GradientTape() as tape:
    tape.watch(input_data)
    outputs = fmu_layer(input_data)
    # gather gradients
    gradients = tape.gradient(outputs, input_data)

# Plot the gradients
fig = make_subplots(rows=1, cols=1)
fig.add_trace(go.Scatter(x=t_vect, y=outputs[0][:,0], name="z", mode="lines"), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=input_x[0], name="x", mode="lines"), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=input_y[0], name="y", mode="lines"), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=gradients[0][:,0], name="dz/dx", mode="lines", line=dict(dash='dot')), row=1, col=1)
fig.add_trace(go.Scatter(x=t_vect, y=gradients[0][:,1], name="dz/dy", mode="lines", line=dict(dash='dot')), row=1, col=1)

fig.update_layout(title="FMU Layer Gradient Test", xaxis_title="Time [s]", yaxis_title="Value")
fig.show()
# Out:
# Queue length:  201

# %%
# Model definition
def get_model(fmu_path, start_time, start_values, parameters, step_size):
    x_in = tf.keras.layers.Input(shape=(None, 1), batch_size=1, name="x_in")
    y_in = tf.keras.layers.Input(shape=(None, 1), batch_size=1, name="y_in")
    inputs = tf.keras.layers.Concatenate(axis=2, name="inputs")([x_in, y_in])

    # Add a dense layer before the FMULayer
    dense_1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(2), name="dense_before")(inputs)

    z_out = FMULayer(
        fmu_path,
        start_time,
        start_values,
        parameters,
        step_size,
        return_sequences=True,
        return_state=False,
        stateful=True,
        name="xy_fmu",
    )(dense_1)

    # custom layer that performs (in1*in2)+parameters[0]
    # z_out = tf.keras.layers.Lambda(lambda x: x[:,:,0]*x[:,:,1]+1.0, name="custom_layer", output_shape=(None,1))(dense_1)

    # Add a dense layer after the FMULayer
    dense_2 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1), name="dense_after")(z_out)

    model = tf.keras.Model(inputs=[x_in, y_in], outputs=dense_2)
    return model

# %%
# create the model with the FMU layer
model = get_model(fmu_path, start_time, [0.0, 0.0], [2.0], step_size)

model.summary()

# compile the model
model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=0.1), loss='mse')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ x_in (InputLayer)   │ (1, None, 1)      │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y_in (InputLayer)   │ (1, None, 1)      │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inputs              │ (1, None, 2)      │          0 │ x_in[0][0],       │
# │ (Concatenate)       │                   │            │ y_in[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_before        │ (1, None, 2)      │          6 │ inputs[0][0]      │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fmu_layer_1         │ (1, None, 1)      │          0 │ dense_before[0][… │
# │ (FMULayer)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_after         │ (1, None, 1)      │          2 │ fmu_layer_1[0][0] │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8 (32.00 B)
#  Trainable params: 8 (32.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# create the input data
input_x = np.cos(t_vect).reshape(1, -1, 1)
input_y = np.sin(t_vect).reshape(1, -1, 1)
input_data = [input_x, input_y]

# %%
# predict
z = model.predict(input_data)
# target
target = 4*((2*input_x+4*input_y+1) * (3*input_y-2*input_x-3)) + 2
# Out:
# Queue length:  0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Add traces for z and target
fig.add_trace(go.Scatter(x=t_vect, y=z.reshape(-1), mode='lines', name='z'))
fig.add_trace(go.Scatter(x=t_vect, y=target[0, :, 0], mode='lines', name='target', line=dict(dash='dash')))

# Update layout
fig.update_layout(
    title="Model Prediction vs Target",
    xaxis_title="Time [s]",
    yaxis_title="z",
    legend=dict(x=0, y=1, traceorder="normal"),
)

# Show the figure
fig.show()

# %%
# TensorBoard callback for live plotting
log_dir = os.path.join(dirname, "logs", "fit", "xy_model")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=10)

# custom TensorBoard callback
class CustomTensorBoard(tf.keras.callbacks.TensorBoard):
    def __init__(self, *args, **kwargs):
        super(CustomTensorBoard, self).__init__(*args, **kwargs)

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 5 == 0:  # Generate images every 5 epochs
            # plot model inputs, outputs and target
            fig = go.Figure()
            fig.add_trace(go.Scatter(x=t_vect, y=model.predict(input_data).reshape(-1), mode='lines', name='z'))
            fig.add_trace(go.Scatter(x=t_vect, y=target[0, :, 0], mode='lines', name='target', line=dict(dash='dash')))
            fig.update_layout(title="Model Prediction vs Target", xaxis_title="Time [s]", yaxis_title="z")

            # add the plot to TensorBoard
            writer = tf.summary.create_file_writer(log_dir)
            with writer.as_default():
                img = tf.image.decode_image(fig.to_image(format="png"), channels=4)
                img = tf.expand_dims(img, 0)  # add batch dimension
                tf.summary.image(name='model', data=img, step=epoch)

        # call the original on_epoch_end method
        super(CustomTensorBoard, self).on_epoch_end(epoch, logs)

# Set the TensorBoard port
os.environ['TENSORBOARD_PORT'] = '6006'

# Start TensorBoard
# %tensorboard --logdir $log_dir --port 6006
# Out:
#       <iframe id="tensorboard-frame-c4da537c1651ddae" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c4da537c1651ddae");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tensorflow.keras.callbacks import EarlyStopping


# fit the model with early stopping
early_stopping = EarlyStopping(monitor='loss', patience=50, restore_best_weights=True)
history = model.fit(input_data, target.reshape(1, -1, 1), epochs=200, batch_size=1, shuffle=False, callbacks=[early_stopping, tensorboard_callback])
# Out:
# Epoch 1/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 23s 23s/step - loss: 1780.6287
# Epoch 2/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1752.9956
# Epoch 3/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1724.2993
# Epoch 4/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1686.8661
# Epoch 5/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 1638.4171
# Epoch 6/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 1577.5675
# Epoch 7/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 1503.8981
# Epoch 8/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 1418.3612
# Epoch 9/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1323.5492
# Epoch 10/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 1223.5640
# Epoch 11/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 1122.8899
# Epoch 12/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 1025.1847
# Epoch 13/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 933.6375
# Epoch 14/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 849.9475
# Epoch 15/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 772.2399
# Epoch 16/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 694.5272
# Epoch 17/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 609.6967
# Epoch 18/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 514.1094
# Epoch 19/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 409.6214
# Epoch 20/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 302.8647
# Epoch 21/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 203.7074
# Epoch 22/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 123.1888
# Epoch 23/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 70.1797
# Epoch 24/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 46.8893
# Epoch 25/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 46.0304
# Epoch 26/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 54.1285
# Epoch 27/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 59.9378
# Epoch 28/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 59.4497
# Epoch 29/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 54.0716
# Epoch 30/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 46.7962
# Epoch 31/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 39.9877
# Epoch 32/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 34.8302
# Epoch 33/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 31.5407
# Epoch 34/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 29.7720
# Epoch 35/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 28.9668
# Epoch 36/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 28.5940
# Epoch 37/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 28.2687
# Epoch 38/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 27.7844
# Epoch 39/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 27.0883
# Epoch 40/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 26.2317
# Epoch 41/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 25.3149
# Epoch 42/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 24.4413
# Epoch 43/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 23.6866
# Epoch 44/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 23.0855
# Epoch 45/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 22.6333
# Epoch 46/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 22.2972
# Epoch 47/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 22.0316
# Epoch 48/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 21.7919
# Epoch 49/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 21.5433
# Epoch 50/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 21.2650
# Epoch 51/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 20.9491
# Epoch 52/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 20.5966
# Epoch 53/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 20.2140
# Epoch 54/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 19.8095
# Epoch 55/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 19.3908
# Epoch 56/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 18.9640
# Epoch 57/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 18.5335
# Epoch 58/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 18.1022
# Epoch 59/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 17.6715
# Epoch 60/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 17.2421
# Epoch 61/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 16.8135
# Epoch 62/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 16.3849
# Epoch 63/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 15.9550
# Epoch 64/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 15.5228
# Epoch 65/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 15.0870
# Epoch 66/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 14.6472
# Epoch 67/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 14.2033
# Epoch 68/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 13.7561
# Epoch 69/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 13.3066
# Epoch 70/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 12.8561
# Epoch 71/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 12.4060
# Epoch 72/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 11.9579
# Epoch 73/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 11.5129
# Epoch 74/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 11.0722
# Epoch 75/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 10.6366
# Epoch 76/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 10.2070
# Epoch 77/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 9.7839
# Epoch 78/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 9.3680
# Epoch 79/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 8.9600
# Epoch 80/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 8.5606
# Epoch 81/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 8.1702
# Epoch 82/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 7.7896
# Epoch 83/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 7.4194
# Epoch 84/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 7.0601
# Epoch 85/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 6.7122
# Epoch 86/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 6.3761
# Epoch 87/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 6.0522
# Epoch 88/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 5.7407
# Epoch 89/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 5.4417
# Epoch 90/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 5.1552
# Epoch 91/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 4.8812
# Epoch 92/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 4.6196
# Epoch 93/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 4.3701
# Epoch 94/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 4.1327
# Epoch 95/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 3.9069
# Epoch 96/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 3.6925
# Epoch 97/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 3.4892
# Epoch 98/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 3.2966
# Epoch 99/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 3.1144
# Epoch 100/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 2.9420
# Epoch 101/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 2.7792
# Epoch 102/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 2.6255
# Epoch 103/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 2.4806
# Epoch 104/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 2.3439
# Epoch 105/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 2.2151
# Epoch 106/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 2.0938
# Epoch 107/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 1.9797
# Epoch 108/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1.8723
# Epoch 109/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 1.7713
# Epoch 110/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 1.6762
# Epoch 111/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1.5869
# Epoch 112/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 1.5029
# Epoch 113/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.4240
# Epoch 114/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.3497
# Epoch 115/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 1.2799
# Epoch 116/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1.2143
# Epoch 117/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 1.1526
# Epoch 118/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1.0945
# Epoch 119/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 1.0399
# Epoch 120/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.9884
# Epoch 121/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.9400
# Epoch 122/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.8944
# Epoch 123/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.8514
# Epoch 124/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.8109
# Epoch 125/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.7727
# Epoch 126/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.7367
# Epoch 127/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.7026
# Epoch 128/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.6705
# Epoch 129/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.6401
# Epoch 130/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.6114
# Epoch 131/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5843
# Epoch 132/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.5586
# Epoch 133/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.5343
# Epoch 134/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.5112
# Epoch 135/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.4894
# Epoch 136/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.4687
# Epoch 137/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.4490
# Epoch 138/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.4304
# Epoch 139/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.4127
# Epoch 140/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 0.3958
# Epoch 141/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.3798
# Epoch 142/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.3646
# Epoch 143/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.3501
# Epoch 144/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.3363
# Epoch 145/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.3231
# Epoch 146/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.3106
# Epoch 147/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.2986
# Epoch 148/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.2872
# Epoch 149/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.2763
# Epoch 150/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.2659
# Epoch 151/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.2560
# Epoch 152/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.2465
# Epoch 153/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2374
# Epoch 154/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.2287
# Epoch 155/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.2204
# Epoch 156/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.2124
# Epoch 157/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 0.2047
# Epoch 158/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 0.1974
# Epoch 159/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 0.1904
# Epoch 160/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.1837
# Epoch 161/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.1772
# Epoch 162/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.1710
# Epoch 163/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.1651
# Epoch 164/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.1594
# Epoch 165/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 0.1539
# Epoch 166/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.1486
# Epoch 167/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.1435
# Epoch 168/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.1387
# Epoch 169/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.1340
# Epoch 170/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.1295
# Epoch 171/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.1251
# Epoch 172/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.1209
# Epoch 173/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.1169
# Epoch 174/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.1130
# Epoch 175/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.1093
# Epoch 176/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1057
# Epoch 177/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 0.1022
# Epoch 178/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0989
# Epoch 179/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0956
# Epoch 180/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 0.0925
# Epoch 181/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0895
# Epoch 182/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.0866
# Epoch 183/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0838
# Epoch 184/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0811
# Epoch 185/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.0785
# Epoch 186/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0760
# Epoch 187/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - loss: 0.0736
# Epoch 188/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 0.0712
# Epoch 189/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.0689
# Epoch 190/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0667
# Epoch 191/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0646
# Epoch 192/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0626
# Epoch 193/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.0606
# Epoch 194/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0587
# Epoch 195/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0568
# Epoch 196/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0550
# Epoch 197/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0533
# Epoch 198/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.0516
# Epoch 199/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0500
# Epoch 200/200
# Queue length:  201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0484

# %%
print("Queue length: ", model.get_layer("fmu_layer_1").cell.gradient_queue.qsize())
# Out:
# Queue length:  401

# %%
import plotly.graph_objects as go

# predict
z = model.predict(input_data)

# Create a figure
fig = go.Figure()

# Add traces for z and target
fig.add_trace(go.Scatter(x=t_vect, y=z.reshape(-1), mode='lines', name='z'))
fig.add_trace(go.Scatter(x=t_vect, y=target[0, :, 0], mode='lines', name='target', line=dict(dash='dash')))

# Update layout
fig.update_layout(
    title="Model Prediction vs Target",
    xaxis_title="Time [s]",
    yaxis_title="z",
    legend=dict(x=0, y=1, traceorder="normal"),
)

# Show the figure
fig.show()
# Out:
# Queue length:  0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step

# %%
# print the model weights by layer
# 4*((2*input_x+4*input_y+1) * (3*input_y-2*input_x-3)) + 2
for layer in model.layers:
    if layer.trainable:
        print(layer.name)
        print(layer.get_weights())
        print("\n")
# Out:
# x_in
# []
#
#
# y_in
# []
#
#
# inputs
# []
#
#
# dense_before
# [array([[ 1.9162699, -1.6521918],
#        [ 3.0274174,  2.0266376]], dtype=float32), array([ 0.44256356, -2.021591  ], dtype=float32)]
#
#
# fmu_layer_1
# []
#
#
# dense_after
# [array([[3.4544835]], dtype=float32), array([1.8198141], dtype=float32)]
